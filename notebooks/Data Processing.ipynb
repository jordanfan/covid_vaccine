# %%
import numpy as np
import pandas as pd
import re 
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize.toktok import ToktokTokenizer
from num2words import num2words
import string
import warnings
import time
import itertools
warnings.filterwarnings("ignore")
pd.set_option("display.max_column", 250)
pd.set_option("display.max_rows", 250)
pd.set_option("display.max_colwidth", 250)

# %% [markdown]
# - Data retrieved from https://vaers.hhs.gov/data/datasets.html
#     - Last pulled 2021-05-02
# - VAERS data use guide: https://vaers.hhs.gov/docs/VAERSDataUseGuide_November2020.pdf
# - Drug Names: https://www.fda.gov/drugs/drug-approvals-and-databases/drugsfda-data-files

# %% [markdown]
# ## Covid-19

# %%
# FUNCTIONS
stop = stopwords.words("english")
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

def read_and_lower(filepath, vaers = True):
    if vaers:
        df = pd.read_csv(filepath, encoding = "ISO-8859-1", converters={"VAERS_ID": lambda x: str(x)})
    else:
        df = pd.read_csv(filepath, encoding = "ISO-8859-1")
    df.columns = df.columns.str.lower()
    for col in df.columns:
        if df[col].dtypes not in ["float64", "int64"]:
            df[col] = df[col].str.lower()            
    return df

def convert_number(text): 
    try:
        return num2words(text)
    except: 
        return text 

def clean_text(text, remove_digits = True, remove_hyphens = True, remove_time = True,
               remove_colons = True, remove_periods = True, remove_slash = True): 
    text = text.astype(str)
    #replace all punctuations with spaces except ".", ":", and "-"  
    text = text.str.replace("[^\w\s\d/.:-]", " ")
    if remove_hyphens: 
        text = text.str.replace("[-]", " ")
    if remove_digits:
        text = text.str.replace("[\d]", " ")
    elif not remove_digits: 
        text = text.apply(lambda x: " ".join([convert_number(word) for word in x.split()]))
    if remove_hyphens: 
        text = text.str.replace("[-]", " ")
    if remove_colons: 
        text = text.str.replace("[:]", " ")
    if remove_time:
        text = text.str.replace("[\d]", " ")
    if remove_periods:
        text = text.str.replace("[.]", " ")
    text = text.str.replace("[^\w\s\d/.:-]", " ")
    #Lemmatize and stem words 
    text = text.apply(lambda x: " ".join([lemmatizer.lemmatize(word) for word in x.split()]))
    text = text.apply(lambda x: " ".join([stemmer.stem(word) for word in x.split()]))
    #remove instances where there is only 1 character
    text = text.apply(lambda x: " ".join([word for word in x.split() if len(word) > 1 and not word.isnumeric()]))
    #take out extra spaces
    text = text.str.replace("\s+", " ")
    #strip leading and trailing spaces if any
    text = text.str.strip()
    #remove stopwords
    text = text.apply(lambda x: " ".join([word for word in x.split() if word not in stop]))
    return text

# %%
patients = read_and_lower("../../src/raw/data/2021VAERSDATA.csv")
symptoms = read_and_lower("../../src/raw/symptoms/2021VAERSSYMPTOMS.csv")
vax = read_and_lower("../../src/raw/vax/2021VAERSVAX.csv")

# %% [markdown]
# ### Vax

# %%
vax.describe()
# Out:
#        vaers_id vax_type vax_manu  vax_lot vax_dose_series vax_route vax_site  \
# count    109785   109785   109785    76767          108854     85325    84434
# unique   108190       43       16     4730               8         9       11
# top     1215401  covid19  moderna  039k20a               1        im       la
# freq         10   109199    45515     2495           68705     59505    59507
#
#                            vax_name
# count                        109785
# unique                           67
# top     covid19 (covid19 (moderna))
# freq                          45515

# %%
multi_id = vax["vaers_id"].value_counts()[vax["vaers_id"].value_counts() > 1].index
multi_id = vax[vax["vaers_id"].isin(multi_id)]
multi_id
# Out:
#        vaers_id    vax_type                     vax_manu  vax_lot  \
# 293     0916918  dtaphepbip  glaxosmithkline biologicals      NaN
# 294     0916918        hibv               sanofi pasteur      NaN
# 295     0916918         rv1  glaxosmithkline biologicals      NaN
# 296     0916918         unk         unknown manufacturer      NaN
# 452     0917087     covid19              pfizer\biontech      NaN
# ...         ...         ...                          ...      ...
# 109468  1243574     covid19              pfizer\biontech   el1283
# 109626  1245083     covid19                      janssen  unknown
# 109627  1245083         unk         unknown manufacturer      NaN
# 109783  1245985     covid19              pfizer\biontech   en6208
# 109784  1245985     covid19              pfizer\biontech   er8737
#
#        vax_dose_series vax_route vax_site  \
# 293                  2       NaN       lg
# 294                  2       NaN       lg
# 295                  2       NaN       lg
# 296                  2       NaN       lg
# 452                  1        im       la
# ...                ...       ...      ...
# 109468               2        im       la
# 109626             unk       NaN      NaN
# 109627             unk       NaN      NaN
# 109783               1        im       ra
# 109784               2        im       ra
#
#                                      vax_name
# 293              dtap + hepb + ipv (pediarix)
# 294                              hib (acthib)
# 295                       rotavirus (rotarix)
# 296             vaccine not specified (other)
# 452       covid19 (covid19 (pfizer-biontech))
# ...                                       ...
# 109468    covid19 (covid19 (pfizer-biontech))
# 109626            covid19 (covid19 (janssen))
# 109627  vaccine not specified (no brand name)
# 109783    covid19 (covid19 (pfizer-biontech))
# 109784    covid19 (covid19 (pfizer-biontech))
#
# [3104 rows x 8 columns]

# %% [markdown]
# Many instances where there are multiple records are when there is a second dose, take row with the latest dose

# %%
vax = vax.sort_values(["vaers_id", "vax_manu"])
vax_reduced = vax.groupby(["vaers_id", "vax_manu"]).last().reset_index()
vax_reduced
# Out:
#        vaers_id         vax_manu vax_type  vax_lot vax_dose_series vax_route  \
# 0       0916600          moderna  covid19  037k20a               1        im
# 1       0916601          moderna  covid19  025l20a               1        im
# 2       0916602  pfizer\biontech  covid19   el1284               1        im
# 3       0916603          moderna  covid19  unknown             unk      None
# 4       0916604          moderna  covid19     None               1        im
# ...         ...              ...      ...      ...             ...       ...
# 108456  1245684          janssen  covid19  unknown             unk      None
# 108457  1245685          janssen  covid19  unknown             unk      None
# 108458  1245686          janssen  covid19  041a21a             unk      None
# 108459  1245687          janssen  covid19  042a21a             unk      None
# 108460  1245985  pfizer\biontech  covid19   er8737               2        im
#
#        vax_site                             vax_name
# 0            la          covid19 (covid19 (moderna))
# 1            ra          covid19 (covid19 (moderna))
# 2            la  covid19 (covid19 (pfizer-biontech))
# 3          None          covid19 (covid19 (moderna))
# 4            la          covid19 (covid19 (moderna))
# ...         ...                                  ...
# 108456     None          covid19 (covid19 (janssen))
# 108457     None          covid19 (covid19 (janssen))
# 108458     None          covid19 (covid19 (janssen))
# 108459     None          covid19 (covid19 (janssen))
# 108460       ra  covid19 (covid19 (pfizer-biontech))
#
# [108461 rows x 8 columns]

# %%
multi_id_reduced = vax_reduced["vaers_id"].value_counts()[vax_reduced["vaers_id"].value_counts() > 1]
multi_id_reduced = vax_reduced[vax_reduced["vaers_id"].isin(multi_id_reduced.index)]
multi_id_reduced
# Out:
#        vaers_id                     vax_manu vax_type  vax_lot  \
# 293     0916918  glaxosmithkline biologicals      rv1     None
# 294     0916918               sanofi pasteur     hibv     None
# 295     0916918         unknown manufacturer      unk     None
# 2641    0919620              pfizer\biontech  covid19   el0140
# 2642    0919620         unknown manufacturer      unk   el0140
# ...         ...                          ...      ...      ...
# 107863  1241260         unknown manufacturer      unk     None
# 107868  1241265                      janssen  covid19  unknown
# 107869  1241265         unknown manufacturer      unk     None
# 108303  1245083                      janssen  covid19  unknown
# 108304  1245083         unknown manufacturer      unk     None
#
#        vax_dose_series vax_route vax_site  \
# 293                  2      None       lg
# 294                  2      None       lg
# 295                  2      None       lg
# 2641                 1        im       la
# 2642                 1      None       un
# ...                ...       ...      ...
# 107863             unk      None     None
# 107868             unk      None     None
# 107869             unk      None     None
# 108303             unk      None     None
# 108304             unk      None     None
#
#                                      vax_name
# 293                       rotavirus (rotarix)
# 294                              hib (acthib)
# 295             vaccine not specified (other)
# 2641      covid19 (covid19 (pfizer-biontech))
# 2642    vaccine not specified (no brand name)
# ...                                       ...
# 107863  vaccine not specified (no brand name)
# 107868            covid19 (covid19 (janssen))
# 107869  vaccine not specified (no brand name)
# 108303            covid19 (covid19 (janssen))
# 108304  vaccine not specified (no brand name)
#
# [521 rows x 8 columns]

# %% [markdown]
# Remaining instances where there are multiple records are due to people taking 2 or more different vaccines, remove from dataset because can't trace back which side effects are associated with which vaccine

# %%
vax_final = vax_reduced[~vax_reduced["vaers_id"].isin(multi_id_reduced["vaers_id"])]
#only looking at covid19 vaccines 
vax_final = vax_final[vax_final["vax_type"] == "covid19"]
vax_final.shape
# Out:
# (107657, 8)

# %% [markdown]
# ### Symptoms

# %%
symptoms
# Out:
#        vaers_id                 symptom1  symptomversion1  \
# 0       0916600                dysphagia             23.1
# 1       0916601                  anxiety             23.1
# 2       0916602         chest discomfort             23.1
# 3       0916603                dizziness             23.1
# 4       0916604  injection site erythema             23.1
# ...         ...                      ...              ...
# 148514  1245686                   chills             23.1
# 148515  1245686                 insomnia             23.1
# 148516  1245687         body temperature             23.1
# 148517  1245687          sars-cov-2 test             23.1
# 148518  1245985                    death             24.0
#
#                           symptom2  symptomversion2                 symptom3  \
# 0                     epiglottitis             23.1                      NaN
# 1                         dyspnoea             23.1                      NaN
# 2                        dysphagia             23.1        pain in extremity
# 3                          fatigue             23.1       mobility decreased
# 4          injection site pruritus             23.1  injection site swelling
# ...                            ...              ...                      ...
# 148514                    headache             23.1               heart rate
# 148515             lymphadenopathy             23.1        pain in extremity
# 148516  body temperature increased             23.1                dizziness
# 148517                         NaN              NaN                      NaN
# 148518                         NaN              NaN                      NaN
#
#         symptomversion3                  symptom4  symptomversion4  \
# 0                   NaN                       NaN              NaN
# 1                   NaN                       NaN              NaN
# 2                  23.1         visual impairment             23.1
# 3                  23.1                       NaN              NaN
# 4                  23.1     injection site warmth             23.1
# ...                 ...                       ...              ...
# 148514             23.1      heart rate increased             23.1
# 148515             23.1  pharyngeal hypoaesthesia             23.1
# 148516             23.1                  headache             23.1
# 148517              NaN                       NaN              NaN
# 148518              NaN                       NaN              NaN
#
#              symptom5  symptomversion5
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 148514  hyperhidrosis             23.1
# 148515            NaN              NaN
# 148516         nausea             23.1
# 148517            NaN              NaN
# 148518            NaN              NaN
#
# [148519 rows x 11 columns]

# %% [markdown]
# Symptom version is just the MedDra dictionary version where the MedDra term was created, doesn't lend much information so can drop them.

# %%
#drop MedDra term versions 
symptoms_dropped = symptoms.drop(columns=["symptomversion1","symptomversion2", "symptomversion3", "symptomversion4", "symptomversion5"])
symptoms_dropped = symptoms_dropped.apply(lambda x: x.str.lower(), axis = 0)

#reduce columns to list of symptoms, removing NA values 
symptoms_list = symptoms_dropped.set_index("vaers_id").unstack().dropna().reset_index(
    name='symptoms')[["vaers_id", "symptoms"]].groupby("vaers_id").agg(lambda x: ' | '.join(x)).reset_index()
symptoms_list
# Out:
#        vaers_id  \
# 0       0916600
# 1       0916601
# 2       0916602
# 3       0916603
# 4       0916604
# ...         ...
# 108184  1245684
# 108185  1245685
# 108186  1245686
# 108187  1245687
# 108188  1245985
#
#                                                                                                                                                  symptoms
# 0                                                                                                                                dysphagia | epiglottitis
# 1                                                                                                                                      anxiety | dyspnoea
# 2                                                                                    chest discomfort | dysphagia | pain in extremity | visual impairment
# 3                                                                                                                dizziness | fatigue | mobility decreased
# 4                                                     injection site erythema | injection site pruritus | injection site swelling | injection site warmth
# ...                                                                                                                                                   ...
# 108184                                                                                                                                dizziness | vertigo
# 108185                                       chills | lethargy | feeling abnormal | pain | headache | somnolence | hyperhidrosis | influenza like illness
# 108186  chills | insomnia | headache | lymphadenopathy | heart rate | pain in extremity | heart rate increased | pharyngeal hypoaesthesia | hyperhidrosis
# 108187                                                    body temperature | sars-cov-2 test | body temperature increased | dizziness | headache | nausea
# 108188                                                                                                                                              death
#
# [108189 rows x 2 columns]

# %%
#remove death from symptoms list because will be predicting deaths from symptoms
symptoms_list["symptoms"] = symptoms_list["symptoms"].astype(str).str.replace(r"[\[\],']", "").str.replace("death", "")

# %% [markdown]
# ### Patients

# %%
patients
# Out:
#        vaers_id    recvdate state  age_yrs  cage_yr  cage_mo sex rpt_date  \
# 0       0916600  01/01/2021    tx     33.0     33.0      NaN   f      NaN
# 1       0916601  01/01/2021    ca     73.0     73.0      NaN   f      NaN
# 2       0916602  01/01/2021    wa     23.0     23.0      NaN   f      NaN
# 3       0916603  01/01/2021    wa     58.0     58.0      NaN   f      NaN
# 4       0916604  01/01/2021    tx     47.0     47.0      NaN   f      NaN
# ...         ...         ...   ...      ...      ...      ...  ..      ...
# 108185  1245684  04/23/2021    hi     73.0      NaN      NaN   m      NaN
# 108186  1245685  04/23/2021    tx      NaN      NaN      NaN   m      NaN
# 108187  1245686  04/23/2021    ny     25.0      NaN      NaN   f      NaN
# 108188  1245687  04/23/2021    ia     18.0      NaN      NaN   f      NaN
# 108189  1245985  04/23/2021   NaN     80.0     80.0      NaN   m      NaN
#
#                                                                                                                                                                                                                                                      symptom_text  \
# 0                                                                                                                                                                 right side of epiglottis swelled up and hinder swallowing pictures taken benadryl tylenol taken
# 1       approximately 30 min post vaccination administration patient demonstrated sob and anxiousness. assessed at time of event: heart sounds normal, lung sounds clear. vitals within normal limits for patient. o2 91% on 3 liters nc continuous flow.   2 ...
# 2       about 15 minutes after receiving the vaccine, the patient complained about her left arm hurting. she also complained of chest tightness and difficulty swallowing. patient also had vision changes. we gave the patient 1 tablet of benadryl 25 mg and...
# 3                                                                                                                                                                                            extreme fatigue, dizziness,. could not lift my left arm for 72 hours
# 4                                                                                                                                                                                                   injection site swelling, redness, warm to the touch and itchy
# ...                                                                                                                                                                                                                                                           ...
# 108185  head spinning/world spinning/ vertigo; slight dizzy; this spontaneous report received from a patient concerned a 73 year old male. the patient's weight was 165 pounds, and height was 175.26 centimeters. the patient's past medical history included...
# 108186  body aches; woke up sweaty and drenched; thought he had the flu; groggy; could not relax; lethargy/out of it all day; chills; headache; this spontaneous report received from a patient concerned a 58 year old male. the patient's weight was 185 pou...
# 108187  swollen lymph node; throat feeling a little numb; sweating a little; heart beating really fast; trouble sleeping; soreness in left arm; chills; headache; this spontaneous report received from a patient concerned a 25 year old female. the patient'...
# 108188  dizziness; severe headache; nausea; temperature of 100; this spontaneous report received from a health care professional concerned an 18 year old female. the patient's height, and weight were not reported. the patient's concurrent conditions incl...
# 108189  this 80 year old   white  male received the covid shot on  4/8/21 and died on  4/18/21.  please refer to the other details submitted within this report and contact the person who submitted this report via email for additional follow up details an...
#
#        died    datedied l_threat er_visit hospital  hospdays x_stay disable  \
# 0       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 1       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 2       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 3       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 4       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# ...     ...         ...      ...      ...      ...       ...    ...     ...
# 108185  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 108186  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 108187  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 108188  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 108189    y  04/20/2021      NaN      NaN      NaN       NaN    NaN     NaN
#
#        recovd    vax_date  onset_date  numdays  \
# 0           y  12/28/2020  12/30/2020      2.0
# 1           y  12/31/2020  12/31/2020      0.0
# 2           u  12/31/2020  12/31/2020      0.0
# 3           y  12/23/2020  12/23/2020      0.0
# 4           n  12/22/2020  12/29/2020      7.0
# ...       ...         ...         ...      ...
# 108185      y         NaN  03/01/2021      NaN
# 108186      n         NaN  03/23/2021      NaN
# 108187      n         NaN  04/05/2021      NaN
# 108188      u         NaN  04/01/2021      NaN
# 108189    NaN  04/08/2021  04/20/2021     12.0
#
#                                                                                                                                                                                                                                                          lab_data  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                            none
# 4                                                                                                                                                                                                                                                             NaN
# ...                                                                                                                                                                                                                                                           ...
# 108185                                                                                                                                                                                                                                                        NaN
# 108186                                                                                                                                                                                                                                                        NaN
# 108187  test date: 20210406; test name: heart rate; result unstructured data: 145 beats per minute; comments: highest rate; the patient had. baseline is 66-82 bpm; test date: 20210406; test name: heart rate; result unstructured data: 91 beats per minute;...
# 108188                                                                                     test date: 202103; test name: sars-cov-2 pcr test; result unstructured data: positive; test date: 202104; test name: body temperature; result unstructured data: 100 f
# 108189                                                                                                                                                                                                                                                        NaN
#
#        v_adminby v_fundby  \
# 0            pvt      NaN
# 1            sen      NaN
# 2            sen      NaN
# 3            wrk      NaN
# 4            pub      NaN
# ...          ...      ...
# 108185       oth      NaN
# 108186       oth      NaN
# 108187       oth      NaN
# 108188       oth      NaN
# 108189       pvt      NaN
#
#                                                        other_meds  \
# 0                                                            none
# 1       patient residing at nursing facility. see patients chart.
# 2                                                            none
# 3                                                            none
# 4                                                              na
# ...                                                           ...
# 108185                                          losartan; norvasc
# 108186                                                        NaN
# 108187                                                        NaN
# 108188                                                        NaN
# 108189                                                        NaN
#
#                                                                                   cur_ill  \
# 0                                                                                    none
# 1                               patient residing at nursing facility. see patients chart.
# 2                                                                                    none
# 3                                                                        kidney infection
# 4                                                                                      na
# ...                                                                                   ...
# 108185  alcohol use (moderate to light.); essential hypertension; food allergy; nonsmoker
# 108186                           alcohol use (once a week.); non-smoker; seasonal allergy
# 108187                                                                     pollen allergy
# 108188                                                                           covid-19
# 108189                                                                                NaN
#
#                                                                                                                                                                                                                                                           history  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                       patient residing at nursing facility. see patients chart.
# 2                                                                                                                                                                                                                                                            none
# 3                                                                                                                                                                                                           diverticulitis, mitral valve prolapse, osteoarthritis
# 4                                                                                                                                                                                                                                                             NaN
# ...                                                                                                                                                                                                                                                           ...
# 108185                                                                                                                                  medical history/concurrent conditions: drug allergy; seasonal asthma; comments: the patient had no history of drug abuse.
# 108186  medical history/concurrent conditions: drug abuse (33 year ago.); comments: no illness at the time of vaccination. no past history of similar event. no adverse event after any previous vaccination. no history of allergy to vaccine drug, or food. ...
# 108187                                                                                                                                                           comments: the patient was not pregnant at the time of reporting and had no known drug allergies.
# 108188                                                                                                                                                                                                                                          comments: unknown
# 108189                                                                                                                                                                                                                                                        NaN
#
#                                                                                      prior_vax  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3       got measles from measel shot, mums from mumps shot, headaches and nausea from flu shot
# 4                                                                                          NaN
# ...                                                                                        ...
# 108185                                                                                     NaN
# 108186                                                                                     NaN
# 108187                                                                                     NaN
# 108188                                                                                     NaN
# 108189                                                                                     NaN
#
#                    splttype  form_vers todays_date birth_defect ofc_visit  \
# 0                       NaN          2  01/01/2021          NaN         y
# 1                       NaN          2  01/01/2021          NaN         y
# 2                       NaN          2  01/01/2021          NaN       NaN
# 3                       NaN          2  01/01/2021          NaN       NaN
# 4                       NaN          2  01/01/2021          NaN       NaN
# ...                     ...        ...         ...          ...       ...
# 108185  usjnjfoc20210347761          2  04/22/2021          NaN       NaN
# 108186  usjnjfoc20210348673          2  04/22/2021          NaN       NaN
# 108187  usjnjfoc20210410875          2  04/14/2021          NaN       NaN
# 108188  usjnjfoc20210413238          2  04/09/2021          NaN       NaN
# 108189                  NaN          2  04/23/2021          NaN       NaN
#
#        er_ed_visit                                                  allergies
# 0              NaN                                          pcn and bee venom
# 1              NaN                                                    "dairy"
# 2                y                                                  shellfish
# 3              NaN  diclofenac, novacaine, lidocaine, pickles, tomatoes, milk
# 4              NaN                                                         na
# ...            ...                                                        ...
# 108185         NaN                                                        NaN
# 108186         NaN                                                        NaN
# 108187         NaN                                                        NaN
# 108188         NaN                                                        NaN
# 108189         NaN                                                        NaN
#
# [108190 rows x 35 columns]

# %%
patients["vaers_id"].value_counts()
# Out:
# 0916600    1
# 1055137    1
# 1055443    1
# 1055421    1
# 1055418    1
#           ..
# 0956765    1
# 0956764    1
# 0956763    1
# 0956762    1
# 1245985    1
# Name: vaers_id, Length: 108190, dtype: int64

# %% [markdown]
# All patient ids are unique

# %%
#Create a column to denote serious side effect, defined as if patient died, have life threatening event, had to go to the er,
#was hospitalized, had a prolonged hospitalization, had a disability, had a birth defect, or had an er/ed visit 

#check only values are Y or blank 
for i in ["died", "l_threat", "er_visit", "hospital", "x_stay", "disable", "birth_defect", "er_ed_visit"]:
    print(patients[i].unique())
# Out:
# [nan 'y']
# [nan 'y']
# [nan 'y']
# [nan 'y']
# [nan 'y']
# [nan 'y']
# [nan 'y']
# [nan 'y']

# %%
patients["temp_list"] = patients[["died", "l_threat", "er_visit", "hospital", "x_stay", 
        "disable", "birth_defect", "er_ed_visit"]].apply(lambda x: np.array(x.values.tolist()), axis = 1)
patients["serious_se"] = patients.apply(lambda x: "died" if 0 in list(np.where(x["temp_list"] == "y")[0]) 
               #"If er_visit is the only option checked, the report is not considered serious"
               else "not serious" if x["er_visit"] == "y" and len(np.where(x["temp_list"] == "y")[0]) == 1 
               else "serious" if len(np.where(x["temp_list"] == "y")[0]) >= 1 
               else "not serious", axis = 1)
patients = patients.drop("temp_list", axis = 1)

# %%
#checking that er_visit serious column filled out correctly 
patients[patients["er_visit"] == "y"][["died", "l_threat", "er_visit", "hospital", "x_stay", 
        "disable", "birth_defect", "er_ed_visit", "serious_se"]]
# Out:
#       died l_threat er_visit hospital x_stay disable birth_defect er_ed_visit  \
# 2855   NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 8145   NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 9675   NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 11839  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 13147  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 18167  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 24665  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 30640  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 34004  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 35548  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 45679  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 49870  NaN      NaN        y      NaN    NaN     NaN          NaN         NaN
# 50668  NaN      NaN        y        y    NaN     NaN          NaN         NaN
# 57639  NaN        y        y      NaN    NaN     NaN          NaN         NaN
# 59062  NaN      NaN        y        y    NaN       y          NaN         NaN
#
#         serious_se
# 2855   not serious
# 8145   not serious
# 9675   not serious
# 11839  not serious
# 13147  not serious
# 18167  not serious
# 24665  not serious
# 30640  not serious
# 34004  not serious
# 35548  not serious
# 45679  not serious
# 49870  not serious
# 50668      serious
# 57639      serious
# 59062      serious

# %%
for i in ["recvdate", "state", 'age_yrs', "cage_yr", "cage_mo", "sex", "rpt_date", "recovd", 
          "vax_date", "onset_date", "numdays", "lab_data", "v_adminby", "v_fundby", "other_meds", 
          "cur_ill", "history", "prior_vax", "splttype", "form_vers", "todays_date", "allergies"]:
    print(i, ":", patients[i].unique())
# Out:
# recvdate : ['01/01/2021' '01/02/2021' '01/03/2021' '01/04/2021' '01/05/2021'
#  8.3000e+01 7.3000e+01 9.2000e+01 1.9389e+04 8.7000e+01 7.4960e+03
#  2.6456e+04 8.0000e+01 9.0160e+03 7.8000e+01 1.1646e+04 8.3380e+03
#  1.9420e+04 1.3950e+04 7.1820e+03 3.8400e+02 4.0220e+03 9.2630e+03
#  3.0492e+04 2.0462e+04 1.5740e+04 1.8669e+04 7.2000e+01 2.7436e+04
#  1.5586e+04 1.4611e+04 8.5000e+01]
# lab_data : ['none' nan
#  'did not seek medical care. treated self at home with benadryl' ...
#  'test date: 20210321; test name: body temperature; result unstructured data: 103 f'
#  'test date: 20210406; test name: heart rate; result unstructured data: 145 beats per minute; comments: highest rate; the patient had. baseline is 66-82 bpm; test date: 20210406; test name: heart rate; result unstructured data: 91 beats per minute; comments: lowest heart rate; the patient had. baseline is 66-82 bpm'
#  'test date: 202103; test name: sars-cov-2 pcr test; result unstructured data: positive; test date: 202104; test name: body temperature; result unstructured data: 100 f']
# v_adminby : ['pvt' 'sen' 'wrk' 'pub' 'oth' 'unk' 'phm' 'mil' 'sch']
# v_fundby : [nan 'oth' 'unk' 'pub' 'pvt']
# other_meds : ['none' 'patient residing at nursing facility. see patients chart.' 'na'
#  ... 'asprin; vitamins; fluticasone; fish oil; calcium; synthroid'
#  'multi vitamins; vitamin d [ergocalciferol]; zyrtec [cetirizine hydrochloride]'
#  'losartan; norvasc']
# cur_ill : ['none' 'patient residing at nursing facility. see patients chart.'
#  'kidney infection' ...
#  'alcohol use (1beer - 2 beers average occasionally.); allergy to nuts; high cholesterol; non-smoker; seasonal allergy; vitamin d deficiency'
#  'alcohol use (moderate to light.); essential hypertension; food allergy; nonsmoker'
#  'alcohol use (once a week.); non-smoker; seasonal allergy']
# history : ['none' 'patient residing at nursing facility. see patients chart.'
#  'diverticulitis, mitral valve prolapse, osteoarthritis' ...
#  'medical history/concurrent conditions: drug allergy; seasonal asthma; comments: the patient had no history of drug abuse.'
#  'medical history/concurrent conditions: drug abuse (33 year ago.); comments: no illness at the time of vaccination. no past history of similar event. no adverse event after any previous vaccination. no history of allergy to vaccine drug, or food. no pre-existing acute illness 30 days prior to vaccination. no history of hospitalization in last 30 days with cause. no family history of any disease(relevant to vaccination) or allergy. no pregnant at the time of vaccination. no currently breastfeeding. no event is covid-19 infection, was it confirmed by test.'
#  'comments: the patient was not pregnant at the time of reporting and had no known drug allergies.']
# prior_vax : [nan
#  'got measles from measel shot, mums from mumps shot, headaches and nausea from flu shot'
#  '20 years old, had similar reactions to flu vaccine.  unknown brand or date.'
#  ...
#  'tetanus vaccine- had shaking chills/felt cold afterwards (~10 yrs ago)'
#  'flu shot cause flu like symptoms'
#  'flu - 2020 - had minor reaction with body ache and swelling, nothing like this j&j']
# splttype : [nan '011j20a' 'unkown' ... 'usjnjfoc20210348673' 'usjnjfoc20210410875'
#  'usjnjfoc20210413238']
# form_vers : [2 1]
# todays_date : ['01/01/2021' '01/01/2020' nan '01/02/2021' '12/09/2020' '12/11/2020'
#  'many and many have a severe response usually  aspirin, nsaids, pcn, codeine, kenalog, tamiflu, tylenol, bupivacaine, lidocaine, medrol dos packet, morphine, dilaudid, clindamycin, bactrim, cipro, clarithormycin, doxcycline, cymbalta, lyrica, synvisc, dexamethosone, (general no steroids),  triamterene-hct2, lasix, nystatin cream.']

# %%
patients["lab_data"].sample(50).unique()
#contains a lot of dates and other test results that include slashes
patients["lab_data_cleaned"] = clean_text(patients["lab_data"], remove_slash = False, remove_digits = False)

# %%
#contains doses of medication
patients["other_meds"].sample(50).unique()
patients["other_meds_cleaned"] = clean_text(patients["other_meds"], remove_digits = False)

# %%
patients["cur_ill"].sample(50).unique()
patients["cur_ill_cleaned"] = clean_text(patients["cur_ill"])

# %%
patients["history"].sample(50).unique()
patients["history_cleaned"] = clean_text(patients["history"])

# %%
patients["prior_vax"].sample(100).unique()
patients["prior_vax_cleaned"] = clean_text(patients["prior_vax"])

# %%
patients["allergies"].sample(50).unique()
patients["allergies_cleaned"] = clean_text(patients["allergies"])

# %%
text_cols = ["lab_data", "other_meds", "cur_ill", "history", "prior_vax", "allergies"]
for col in text_cols: 
    patients[f'{col}_nchar'] = patients[col].astype(str).apply(lambda x: len(x))

# %%
final_df = vax_final.merge(symptoms_list, how="left", on = "vaers_id").merge(patients, how = "left", on = "vaers_id")
final_df
# Out:
#        vaers_id         vax_manu vax_type  vax_lot vax_dose_series vax_route  \
# 0       0916600          moderna  covid19  037k20a               1        im
# 1       0916601          moderna  covid19  025l20a               1        im
# 2       0916602  pfizer\biontech  covid19   el1284               1        im
# 3       0916603          moderna  covid19  unknown             unk      None
# 4       0916604          moderna  covid19     None               1        im
# ...         ...              ...      ...      ...             ...       ...
# 107652  1245684          janssen  covid19  unknown             unk      None
# 107653  1245685          janssen  covid19  unknown             unk      None
# 107654  1245686          janssen  covid19  041a21a             unk      None
# 107655  1245687          janssen  covid19  042a21a             unk      None
# 107656  1245985  pfizer\biontech  covid19   er8737               2        im
#
#        vax_site                             vax_name  \
# 0            la          covid19 (covid19 (moderna))
# 1            ra          covid19 (covid19 (moderna))
# 2            la  covid19 (covid19 (pfizer-biontech))
# 3          None          covid19 (covid19 (moderna))
# 4            la          covid19 (covid19 (moderna))
# ...         ...                                  ...
# 107652     None          covid19 (covid19 (janssen))
# 107653     None          covid19 (covid19 (janssen))
# 107654     None          covid19 (covid19 (janssen))
# 107655     None          covid19 (covid19 (janssen))
# 107656       ra  covid19 (covid19 (pfizer-biontech))
#
#                                                                                                                                                  symptoms  \
# 0                                                                                                                                dysphagia | epiglottitis
# 1                                                                                                                                      anxiety | dyspnoea
# 2                                                                                    chest discomfort | dysphagia | pain in extremity | visual impairment
# 3                                                                                                                dizziness | fatigue | mobility decreased
# 4                                                     injection site erythema | injection site pruritus | injection site swelling | injection site warmth
# ...                                                                                                                                                   ...
# 107652                                                                                                                                dizziness | vertigo
# 107653                                       chills | lethargy | feeling abnormal | pain | headache | somnolence | hyperhidrosis | influenza like illness
# 107654  chills | insomnia | headache | lymphadenopathy | heart rate | pain in extremity | heart rate increased | pharyngeal hypoaesthesia | hyperhidrosis
# 107655                                                    body temperature | sars-cov-2 test | body temperature increased | dizziness | headache | nausea
# 107656
#
#           recvdate state  age_yrs  cage_yr  cage_mo sex rpt_date  \
# 0       01/01/2021    tx     33.0     33.0      NaN   f      NaN
# 1       01/01/2021    ca     73.0     73.0      NaN   f      NaN
# 2       01/01/2021    wa     23.0     23.0      NaN   f      NaN
# 3       01/01/2021    wa     58.0     58.0      NaN   f      NaN
# 4       01/01/2021    tx     47.0     47.0      NaN   f      NaN
# ...            ...   ...      ...      ...      ...  ..      ...
# 107652  04/23/2021    hi     73.0      NaN      NaN   m      NaN
# 107653  04/23/2021    tx      NaN      NaN      NaN   m      NaN
# 107654  04/23/2021    ny     25.0      NaN      NaN   f      NaN
# 107655  04/23/2021    ia     18.0      NaN      NaN   f      NaN
# 107656  04/23/2021   NaN     80.0     80.0      NaN   m      NaN
#
#                                                                                                                                                                                                                                                      symptom_text  \
# 0                                                                                                                                                                 right side of epiglottis swelled up and hinder swallowing pictures taken benadryl tylenol taken
# 1       approximately 30 min post vaccination administration patient demonstrated sob and anxiousness. assessed at time of event: heart sounds normal, lung sounds clear. vitals within normal limits for patient. o2 91% on 3 liters nc continuous flow.   2 ...
# 2       about 15 minutes after receiving the vaccine, the patient complained about her left arm hurting. she also complained of chest tightness and difficulty swallowing. patient also had vision changes. we gave the patient 1 tablet of benadryl 25 mg and...
# 3                                                                                                                                                                                            extreme fatigue, dizziness,. could not lift my left arm for 72 hours
# 4                                                                                                                                                                                                   injection site swelling, redness, warm to the touch and itchy
# ...                                                                                                                                                                                                                                                           ...
# 107652  head spinning/world spinning/ vertigo; slight dizzy; this spontaneous report received from a patient concerned a 73 year old male. the patient's weight was 165 pounds, and height was 175.26 centimeters. the patient's past medical history included...
# 107653  body aches; woke up sweaty and drenched; thought he had the flu; groggy; could not relax; lethargy/out of it all day; chills; headache; this spontaneous report received from a patient concerned a 58 year old male. the patient's weight was 185 pou...
# 107654  swollen lymph node; throat feeling a little numb; sweating a little; heart beating really fast; trouble sleeping; soreness in left arm; chills; headache; this spontaneous report received from a patient concerned a 25 year old female. the patient'...
# 107655  dizziness; severe headache; nausea; temperature of 100; this spontaneous report received from a health care professional concerned an 18 year old female. the patient's height, and weight were not reported. the patient's concurrent conditions incl...
# 107656  this 80 year old   white  male received the covid shot on  4/8/21 and died on  4/18/21.  please refer to the other details submitted within this report and contact the person who submitted this report via email for additional follow up details an...
#
#        died    datedied l_threat er_visit hospital  hospdays x_stay disable  \
# 0       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 1       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 2       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 3       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 4       NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# ...     ...         ...      ...      ...      ...       ...    ...     ...
# 107652  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 107653  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 107654  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 107655  NaN         NaN      NaN      NaN      NaN       NaN    NaN     NaN
# 107656    y  04/20/2021      NaN      NaN      NaN       NaN    NaN     NaN
#
#        recovd    vax_date  onset_date  numdays  \
# 0           y  12/28/2020  12/30/2020      2.0
# 1           y  12/31/2020  12/31/2020      0.0
# 2           u  12/31/2020  12/31/2020      0.0
# 3           y  12/23/2020  12/23/2020      0.0
# 4           n  12/22/2020  12/29/2020      7.0
# ...       ...         ...         ...      ...
# 107652      y         NaN  03/01/2021      NaN
# 107653      n         NaN  03/23/2021      NaN
# 107654      n         NaN  04/05/2021      NaN
# 107655      u         NaN  04/01/2021      NaN
# 107656    NaN  04/08/2021  04/20/2021     12.0
#
#                                                                                                                                                                                                                                                          lab_data  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                             NaN
# 3                                                                                                                                                                                                                                                            none
# 4                                                                                                                                                                                                                                                             NaN
# ...                                                                                                                                                                                                                                                           ...
# 107652                                                                                                                                                                                                                                                        NaN
# 107653                                                                                                                                                                                                                                                        NaN
# 107654  test date: 20210406; test name: heart rate; result unstructured data: 145 beats per minute; comments: highest rate; the patient had. baseline is 66-82 bpm; test date: 20210406; test name: heart rate; result unstructured data: 91 beats per minute;...
# 107655                                                                                     test date: 202103; test name: sars-cov-2 pcr test; result unstructured data: positive; test date: 202104; test name: body temperature; result unstructured data: 100 f
# 107656                                                                                                                                                                                                                                                        NaN
#
#        v_adminby v_fundby  \
# 0            pvt      NaN
# 1            sen      NaN
# 2            sen      NaN
# 3            wrk      NaN
# 4            pub      NaN
# ...          ...      ...
# 107652       oth      NaN
# 107653       oth      NaN
# 107654       oth      NaN
# 107655       oth      NaN
# 107656       pvt      NaN
#
#                                                        other_meds  \
# 0                                                            none
# 1       patient residing at nursing facility. see patients chart.
# 2                                                            none
# 3                                                            none
# 4                                                              na
# ...                                                           ...
# 107652                                          losartan; norvasc
# 107653                                                        NaN
# 107654                                                        NaN
# 107655                                                        NaN
# 107656                                                        NaN
#
#                                                                                   cur_ill  \
# 0                                                                                    none
# 1                               patient residing at nursing facility. see patients chart.
# 2                                                                                    none
# 3                                                                        kidney infection
# 4                                                                                      na
# ...                                                                                   ...
# 107652  alcohol use (moderate to light.); essential hypertension; food allergy; nonsmoker
# 107653                           alcohol use (once a week.); non-smoker; seasonal allergy
# 107654                                                                     pollen allergy
# 107655                                                                           covid-19
# 107656                                                                                NaN
#
#                                                                                                                                                                                                                                                           history  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                       patient residing at nursing facility. see patients chart.
# 2                                                                                                                                                                                                                                                            none
# 3                                                                                                                                                                                                           diverticulitis, mitral valve prolapse, osteoarthritis
# 4                                                                                                                                                                                                                                                             NaN
# ...                                                                                                                                                                                                                                                           ...
# 107652                                                                                                                                  medical history/concurrent conditions: drug allergy; seasonal asthma; comments: the patient had no history of drug abuse.
# 107653  medical history/concurrent conditions: drug abuse (33 year ago.); comments: no illness at the time of vaccination. no past history of similar event. no adverse event after any previous vaccination. no history of allergy to vaccine drug, or food. ...
# 107654                                                                                                                                                           comments: the patient was not pregnant at the time of reporting and had no known drug allergies.
# 107655                                                                                                                                                                                                                                          comments: unknown
# 107656                                                                                                                                                                                                                                                        NaN
#
#                                                                                      prior_vax  \
# 0                                                                                          NaN
# 1                                                                                          NaN
# 2                                                                                          NaN
# 3       got measles from measel shot, mums from mumps shot, headaches and nausea from flu shot
# 4                                                                                          NaN
# ...                                                                                        ...
# 107652                                                                                     NaN
# 107653                                                                                     NaN
# 107654                                                                                     NaN
# 107655                                                                                     NaN
# 107656                                                                                     NaN
#
#                    splttype  form_vers todays_date birth_defect ofc_visit  \
# 0                       NaN          2  01/01/2021          NaN         y
# 1                       NaN          2  01/01/2021          NaN         y
# 2                       NaN          2  01/01/2021          NaN       NaN
# 3                       NaN          2  01/01/2021          NaN       NaN
# 4                       NaN          2  01/01/2021          NaN       NaN
# ...                     ...        ...         ...          ...       ...
# 107652  usjnjfoc20210347761          2  04/22/2021          NaN       NaN
# 107653  usjnjfoc20210348673          2  04/22/2021          NaN       NaN
# 107654  usjnjfoc20210410875          2  04/14/2021          NaN       NaN
# 107655  usjnjfoc20210413238          2  04/09/2021          NaN       NaN
# 107656                  NaN          2  04/23/2021          NaN       NaN
#
#        er_ed_visit                                                  allergies  \
# 0              NaN                                          pcn and bee venom
# 1              NaN                                                    "dairy"
# 2                y                                                  shellfish
# 3              NaN  diclofenac, novacaine, lidocaine, pickles, tomatoes, milk
# 4              NaN                                                         na
# ...            ...                                                        ...
# 107652         NaN                                                        NaN
# 107653         NaN                                                        NaN
# 107654         NaN                                                        NaN
# 107655         NaN                                                        NaN
# 107656         NaN                                                        NaN
#
#          serious_se  \
# 0       not serious
# 1       not serious
# 2           serious
# 3       not serious
# 4       not serious
# ...             ...
# 107652  not serious
# 107653  not serious
# 107654  not serious
# 107655  not serious
# 107656         died
#
#                                                                                                                                                                                                                                                  lab_data_cleaned  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                                                                             nan
# 2                                                                                                                                                                                                                                                             nan
# 3                                                                                                                                                                                                                                                            none
# 4                                                                                                                                                                                                                                                             nan
# ...                                                                                                                                                                                                                                                           ...
# 107652                                                                                                                                                                                                                                                        nan
# 107653                                                                                                                                                                                                                                                        nan
# 107654  test date twenti million two hundr ten thousand four hundr six test name heart rate result unstructur data one hundr forti five beat per minut comment highest rate patient baselin sixti six eighti two bpm test date twenti million two hundr ten th...
# 107655                                    test date two hundr two thousand one hundr three test name sar cov two pcr test result unstructur data posit test date two hundr two thousand one hundr four test name bodi temperatur result unstructur data one hundr
# 107656                                                                                                                                                                                                                                                        nan
#
#                                 other_meds_cleaned  \
# 0                                             none
# 1       patient resid nurs facil see patient chart
# 2                                             none
# 3                                             none
# 4                                               na
# ...                                            ...
# 107652                            losartan norvasc
# 107653                                         nan
# 107654                                         nan
# 107655                                         nan
# 107656                                         nan
#
#                                                        cur_ill_cleaned  \
# 0                                                                 none
# 1                           patient resid nurs facil see patient chart
# 2                                                                 none
# 3                                                        kidney infect
# 4                                                                   na
# ...                                                                ...
# 107652  alcohol use moder light essenti hypertens food allergi nonsmok
# 107653                  alcohol use onc week non smoker season allergi
# 107654                                                  pollen allergi
# 107655                                                           covid
# 107656                                                             nan
#
#                                                                                                                                                                                                                                                   history_cleaned  \
# 0                                                                                                                                                                                                                                                            none
# 1                                                                                                                                                                                                                      patient resid nurs facil see patient chart
# 2                                                                                                                                                                                                                                                            none
# 3                                                                                                                                                                                                                       diverticul mitral valv prolaps osteoarthr
# 4                                                                                                                                                                                                                                                             nan
# ...                                                                                                                                                                                                                                                           ...
# 107652                                                                                                                                                                  medic history/concurr condit drug allergi season asthma comment patient histori drug abus
# 107653  medic history/concurr condit drug abus year ago comment ill time vaccin past histori similar event advers event ani previou vaccin histori allergi vaccin drug food pre exist acut ill day prior vaccin histori hospit last day caus famili histori an...
# 107654                                                                                                                                                                                                 comment patient wa pregnant time report known drug allergi
# 107655                                                                                                                                                                                                                                            comment unknown
# 107656                                                                                                                                                                                                                                                        nan
#
#                                                   prior_vax_cleaned  \
# 0                                                               nan
# 1                                                               nan
# 2                                                               nan
# 3       got measl measel shot mum mump shot headach nausea flu shot
# 4                                                               nan
# ...                                                             ...
# 107652                                                          nan
# 107653                                                          nan
# 107654                                                          nan
# 107655                                                          nan
# 107656                                                          nan
#
#                                      allergies_cleaned  lab_data_nchar  \
# 0                                        pcn bee venom               4
# 1                                                dairi               3
# 2                                            shellfish               3
# 3       diclofenac novacain lidocain pickl tomato milk               4
# 4                                                   na               3
# ...                                                ...             ...
# 107652                                             nan               3
# 107653                                             nan               3
# 107654                                             nan             314
# 107655                                             nan             166
# 107656                                             nan               3
#
#         other_meds_nchar  cur_ill_nchar  history_nchar  prior_vax_nchar  \
# 0                      4              4              4                3
# 1                     57             57             57                3
# 2                      4              4              4                3
# 3                      4             16             53               86
# 4                      2              2              3                3
# ...                  ...            ...            ...              ...
# 107652                17             81            121                3
# 107653                 3             56            559                3
# 107654                 3             14             96                3
# 107655                 3              8             17                3
# 107656                 3              3              3                3
#
#         allergies_nchar
# 0                    17
# 1                     7
# 2                     9
# 3                    57
# 4                     2
# ...                 ...
# 107652                3
# 107653                3
# 107654                3
# 107655                3
# 107656                3
#
# [107657 rows x 56 columns]

# %%
#remove people who live in a state with low representation 
final_df = final_df[~final_df["state"].isin(final_df["state"].value_counts().tail(8).index)]
final_df["vax_dose_series"] = final_df["vax_dose_series"].apply(lambda x: "2+" if x in ["2", "3", "4", "5", "6", "7+"] else x)
final_df["vax_dose_series"] = final_df["vax_dose_series"].fillna("unk")
final_df["vax_lot"] = final_df["vax_lot"].fillna("")
final_df["vax_lot"] = final_df["vax_lot"].str.replace(",", "")
final_df["symptoms"] = final_df["symptoms"].fillna("")
final_df["age_yrs"] = final_df["age_yrs"].fillna(0)
final_df["numdays"] = final_df["numdays"].fillna(-1)
final_df["state"] = final_df["state"].fillna("unk")
for i in final_df.columns:
    if "_cleaned" in i:
        final_df[i] = final_df[i].fillna("none")
        final_df[i] = final_df[i].apply(lambda x: "none" if x == "" else x)

# %%
final_df = final_df[["vaers_id", "vax_manu", "vax_lot", "vax_dose_series", "symptoms", "state", "age_yrs", 
          "sex", "numdays", "lab_data", "lab_data_cleaned", "other_meds", "other_meds_cleaned", "cur_ill", "cur_ill_cleaned", 
           "history", "history_cleaned", "prior_vax", "prior_vax_cleaned", "allergies", "allergies_cleaned", "serious_se"]]

# %%
final_df.isnull().sum()
# Out:
# vaers_id                   0
# vax_manu                   0
# vax_lot                    0
# vax_dose_series            0
# symptoms                   0
# state                      0
# age_yrs                    0
# sex                        0
# numdays                    0
# lab_data               62511
# lab_data_cleaned           0
# other_meds             40438
# other_meds_cleaned         0
# cur_ill                52792
# cur_ill_cleaned            0
# history                31874
# history_cleaned            0
# prior_vax             102495
# prior_vax_cleaned          0
# allergies              44067
# allergies_cleaned          0
# serious_se                 0
# dtype: int64

# %%
final_df.to_csv("../../src/processed/covid_vaccine_symptoms.csv", index = False)

# %% [markdown]
# ### Map Drugs to Active Ingredients and Group

# %%
final_df = pd.read_csv("../../src/processed/covid_vaccine_symptoms.csv")

# %%
drugnames = read_and_lower("../../src/raw/drugs/drugnames.csv", vaers= False)[["drugname", "activeingredient"]]
drug_stem = read_and_lower("../../src/processed/drug_stems_cleaned.csv", vaers = False)

# %%
drugnames["drugname_cleaned"] = clean_text(drugnames["drugname"])
drugnames["activeingredient_cleaned"] = clean_text(drugnames["activeingredient"])
drugnames_cleaned = drugnames[["drugname_cleaned", "activeingredient_cleaned"]].drop_duplicates()

#For short drugs, split other_meds_cleaned into words and need to match short drug name exactly 
short_drugs = drugnames_cleaned[drugnames_cleaned["drugname_cleaned"].apply(lambda x: len(x) <= 5)]
short_drugs = short_drugs[short_drugs["drugname_cleaned"] != ""]
short_drugs = dict(zip(short_drugs["drugname_cleaned"], short_drugs["activeingredient_cleaned"]))
#For long drugs, just search for long drug name in entire text to see if there's a match 
long_drugs = drugnames_cleaned[drugnames_cleaned["drugname_cleaned"].apply(lambda x: len(x) > 5)]
long_drugs = dict(zip(long_drugs["drugname_cleaned"], long_drugs["activeingredient_cleaned"]))

# %%
start = time.time()
print("Picking out and converting short drug names")
final_df["meds_list"] = final_df["other_meds_cleaned"].astype(str).str.split().apply(lambda x: np.array([short_drugs[i] if i in short_drugs.keys() else "" for i in x]))
print(f'Time elapsed: {round(time.time() - start, 1)} seconds')
start = time.time()
print("Picking out and converting long drug names")
final_df["meds_list2"] = final_df["other_meds_cleaned"].astype(str).apply(lambda x: np.unique(np.array([long_drugs[i] if i in x else "" for i in long_drugs.keys()])))
print(f'Time elapsed: {round(time.time() - start, 1)} seconds')
start = time.time()
print("Picking out active ingredients")
final_df["meds_list3"] = final_df["other_meds_cleaned"].astype(str).apply(lambda x: np.unique(np.array([i if i in x else "" for i in (list(short_drugs.values()) + list(long_drugs.values()))])))
print(f'Time elapsed: {round(time.time() - start, 1)} seconds')
start = time.time()
print("Combining lists and removing empty strings")
final_df["active_ingredients"] = final_df.apply(lambda x: list(np.unique(np.concatenate((x["meds_list"], x["meds_list2"], x["meds_list3"]), axis = 0))), axis = 1)
final_df["active_ingredients"] = final_df["active_ingredients"].apply(lambda x: list(filter(None, x)))
print(f'Time elapsed: {round(time.time() - start, 1)} seconds')
# Out:
# Picking out and converting short drug names
# Time elapsed: 0.9 seconds
# Picking out and converting long drug names
# Time elapsed: 238.1 seconds
# Picking out active ingredients
# Time elapsed: 212.6 seconds
# Combining lists and removing empty strings
# Time elapsed: 5.1 seconds

# %%
#convert active ingredients to corresponding drug group based on active ingredient's name  
prefix_dict = dict(zip(drug_stem[drug_stem["pos"] == "prefix"]["stem"], drug_stem[drug_stem["pos"] == "prefix"]["definition"]))
suffix_dict = dict(zip(drug_stem[drug_stem["pos"] == "suffix"]["stem"], drug_stem[drug_stem["pos"] == "suffix"]["definition"]))
middle_dict = dict(zip(drug_stem[drug_stem["pos"] == "middle"]["stem"], drug_stem[drug_stem["pos"] == "middle"]["definition"]))

def dict_lookup(dict_, active_ing_list, type_):
    '''
    Determines which stems in the drug stem dictionary are present in a list of active ingredients
    
    Inputs:
        dict_ (dict): drug stem dictionary, contains the generic drug stem as the keys and the drug group as values 
        active_ing_list (list): list of active ingredients to iterate through and check if drug stems are present
        type_ (str): type of drug stem dictionary, i.e. prefix, middle, suffix 
    
    Outputs:
        lookup_keys (list): list of dictionary keys that are present in the active_ing_list to later convert to groups 
    '''
    keys = list(dict_.keys())
    #if the dictionary is a prefix drug stem, check to see if each item in active_ing_list starts with any of the keys
    if type_ == "prefix":
        key_bool = np.array([np.array([i.startswith(j) for j in keys]) for i in active_ing_list])
    #if the dictionary is a suffix drug stem, check to see if each item in active_ing_list ends with any of the keys 
    if type_ == "suffix": 
        key_bool = np.array([np.array([i.endswith(j) for j in keys]) for i in active_ing_list])
    #if the dictionary is a middle drug stem, check to see if each item in active_ing_list contains any of the keys
    if type_ == "middle": 
        key_bool = np.array([np.array([j in i[1:-1] for j in keys]) for i in active_ing_list])
    lookup_keys = list(itertools.chain(*[list(np.array(keys)[i]) for i in key_bool]))
    return lookup_keys

def translate_drug_group(active_ing_list): 
    '''
    Takes in a list of drug active ingredients and returns list of all drug groups the active ingredients are part of 
    
    Inputs: 
        active_ing_list (list): list of active ingredients to iterate through and list out drug groups ingredients belong to
    
    Outputs: 
        converted (list): list of all drug groups that are present in the active ingredients list 
    '''
    #get the drug stem keys for each prefix, middle, and suffix dictionary 
    prefix_keys = dict_lookup(prefix_dict, active_ing_list, "prefix")
    suffix_keys = dict_lookup(suffix_dict, active_ing_list, "suffix")
    middle_keys = dict_lookup(middle_dict, active_ing_list, "middle")
    #convert to drug group based off of drug stem keys 
    converted = [prefix_dict[key] for key in prefix_keys]
    converted.extend([suffix_dict[key] for key in suffix_keys])
    converted.extend([middle_dict[key] for key in middle_keys])
    return converted

# %%
final_df["drug_group"] = final_df["active_ingredients"].apply(lambda x: translate_drug_group(re.split(' ', ' '.join(x))) if len(x) > 0 else x)

# %% [markdown]
# * Could further process and pick out active ingredients by using fuzzywuzzy to handle spelling errors for long drug names, however this could introduce inaccurate matching and arduous cleaning process

# %%
final_df["active_ingredients_cleaned"] = clean_text(final_df["active_ingredients"].apply(lambda x: ", ".join(i for i in x)))
final_df["drug_group_cleaned"] = clean_text(final_df["drug_group"].apply(lambda x: ", ".join(i for i in x)))

# %%
final_df.to_csv("../../src/processed/covid_vaccine_symptoms 2.csv", index = False)
